# %% [markdown]
# <h2>Practice</h2>
#
# Use the <b>linear approximation</b> of sin(𝑥) around 𝑎 = 0 to show that sin(𝑥)/𝑥 ≈ 1 for 𝑥 ≈ 0.
#
# <hr/>

# %% [markdown]
# <h3>Imports</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Code</h3>

# %%
π = np.pi
num_points = 400

x = np.linspace(-π, π, num_points)

# Calculate function values
y = np.sin(x)
y_approx_linear = x
y_div_x = np.sin(x) / x

# Print each (x, y) pair for approximation
for i in range(len(x)):
    print(f"For {x[i]:.16f}, {y_div_x[i]:.16f}")

# Plot functions and approximations
plt.plot(x, y, label="sin(x) or Analytic")
plt.plot(x, y_approx_linear, label="Linear Approximation")
plt.plot(x, y_div_x, label="sin(x) / x")
plt.plot(x, y_div_x, linestyle='--', label="sin(x) / x Approximation")

plt.xlabel("x")
plt.ylabel("y")
title = "Taylor Series Approximations of sin(x) (a=0)"
plt.title(title)
plt.legend()

# Plot with grid
plt.grid(True)
plt.show()
# Out:
# For -3.1415926535897931, 0.0000000000000000
# For -3.1258453219928519, 0.0050375751676089
# For -3.1100979903959103, 0.0101249082453736
# For -3.0943506587989691, 0.0152614973103381
# For -3.0786033272020279, 0.0204468307989813
# For -3.0628559956050867, 0.0256803875752862
# For -3.0471086640081451, 0.0309616370006850
# For -3.0313613324112039, 0.0362900390058670
# For -3.0156140008142627, 0.0416650441644389
# For -2.9998666692173215, 0.0470860937684257
# For -2.9841193376203798, 0.0525526199055998
# For -2.9683720060234386, 0.0580640455386255
# For -2.9526246744264975, 0.0636197845860081
# For -2.9368773428295558, 0.0692192420048321
# For -2.9211300112326146, 0.0748618138752750
# For -2.9053826796356734, 0.0805468874868862
# For -2.8896353480387322, 0.0862738414266116
# For -2.8738880164417906, 0.0920420456685538
# For -2.8581406848448494, 0.0978508616654494
# For -2.8423933532479082, 0.1036996424418518
# For -2.8266460216509666, 0.1095877326890001
# ...
